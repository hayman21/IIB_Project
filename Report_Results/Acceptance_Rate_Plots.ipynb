# %%
import matplotlib.pyplot as plt

# Sample data
iterations = [500, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7500, 9000, 10000]
acceptance_rate = [1.6, 0.9, 0.867, 0.6, 0.36, 0.43,0.28, 0.1,0.1, 0.17,0.1, 0.08]

iterations1 = [500, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7500, 9000, 10000]
acceptance_rate1 = [3.8, 2.5, 1.6, 1.45, 1.24, 1.35, 1.4,1.08, 0.95,1.15,0.6, 0.34]

iterations2 = [500, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7500, 9000, 10000]
acceptance_rate2 = [8, 4.9, 4.5, 4, 3, 3.5, 3.2, 2.8, 3,2.9,2.1, 1.5]

iterations3 = [500, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7500, 9000, 10000]
acceptance_rate3 = [5.2, 3.5, 2.8, 2.87, 2.34, 2.4, 2.3,2.2, 2,1.4,1, 0.7]

iterations4 = [500, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7500, 9000, 10000]
acceptance_rate4 = [3.4, 2.3, 1.38, 1.2, 0.8, 1,0.75, 0.86, 0.8,0.78,0.45, 0.27]

# Plotting the line graph
plt.figure(figsize=(12, 6))
plt.plot(iterations, acceptance_rate, marker='o', label='kappa = 0.2, delta = 1.2, gamma = 0.3')
plt.plot(iterations1, acceptance_rate1, marker='o', label='kappa = 0.5, delta = 2.1, gamma = 1.25')
plt.plot(iterations2, acceptance_rate2, marker='o', label='kappa = 0.9, delta = 0.8, gamma = 1.0')
plt.plot(iterations3, acceptance_rate3, marker='o', label='kappa = 0.35, delta = 1.7, gamma = 0.5')
plt.plot(iterations4, acceptance_rate4, marker='o', label='kappa = 0.4, delta = 2.3, gamma = 0.65')
plt.xlabel('Number of Iterations', fontsize=12)
plt.ylabel('Acceptance Rate (%)', fontsize=12)
plt.title('Acceptance Rate vs. Number of Iterations')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
iterations = [500, 1000, 2000, 4000, 6000, 8000, 10000]
acceptance_rate = [0.3, 14.3, 13.6, 13.3, 13.1, 13.1, 14]

iterations1 = [500, 1000, 2000, 4000, 6000, 8000, 10000]
acceptance_rate1 = [11, 11.2, 9.85, 9.13, 9.3, 9.3, 9.44]

iterations2 = [500, 1000, 2000, 4000, 6000, 8000, 10000]
acceptance_rate2 = [18.2, 17.8, 18.2, 17.5, 17, 17, 18]

iterations3 = [500, 1000, 2000, 4000, 6000, 8000, 10000]
acceptance_rate3 = [6.2, 6.8, 6.5, 7, 7.1, 7, 5.8]

iterations4 = [500, 1000, 2000, 4000, 6000, 8000, 10000]
acceptance_rate4 = [10.5, 7.8, 7.6, 8.2, 8, 8, 8.3]

# Plotting the line graph
plt.figure(figsize=(12, 6))
plt.plot(iterations, acceptance_rate, marker='o', label='kappa = 0.2, delta = 1.2, gamma = 0.3')
plt.plot(iterations1, acceptance_rate1, marker='o', label='kappa = 0.5, delta = 2.1, gamma = 1.25')
plt.plot(iterations2, acceptance_rate2, marker='o', label='kappa = 0.9, delta = 0.8, gamma = 1.0')
plt.plot(iterations3, acceptance_rate3, marker='o', label='kappa = 0.35, delta = 1.7, gamma = 0.5')
plt.plot(iterations4, acceptance_rate4, marker='o', label='kappa = 0.4, delta = 2.3, gamma = 0.65')
plt.xlabel('Number of Iterations', fontsize=12)
plt.ylabel('Acceptance Rate (%)', fontsize=12)
plt.title('Acceptance Rate vs. Number of Iterations')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
iterations = [2, 4, 5, 8, 10]
acceptance_rate = [0.3, 5.35, 5.66, 9.05, 8.95]

iterations1 = [2, 4, 5, 8, 10]
acceptance_rate1 = [5.7, 13.7, 14.86, 11.7, 9.8]

iterations2 = [2, 4, 5, 8, 10]
acceptance_rate2 = [26.85, 21.7, 18.86, 12.45, 10]

iterations3 = [2, 4, 5, 8, 10]
acceptance_rate3 = [13.5, 12, 11.5, 10.4, 10]

iterations4 = [2, 4, 5, 8, 10]
acceptance_rate4 = [0.55, 6.2, 6.68, 9.32, 9.5]

# Plotting the line graph
plt.figure(figsize=(12, 6))
plt.plot(iterations, acceptance_rate, marker='o', label='kappa = 0.2, delta = 1.2, gamma = 0.3')
plt.plot(iterations1, acceptance_rate1, marker='o', label='kappa = 0.5, delta = 2.1, gamma = 1.25')
plt.plot(iterations2, acceptance_rate2, marker='o', label='kappa = 0.9, delta = 0.8, gamma = 1.0')
plt.plot(iterations3, acceptance_rate3, marker='o', label='kappa = 0.35, delta = 1.7, gamma = 0.5')
plt.plot(iterations4, acceptance_rate4, marker='o', label='kappa = 0.4, delta = 2.3, gamma = 0.65')
plt.xlabel('Number of Split Intervals', fontsize=12)
plt.ylabel('Acceptance Rate (%)', fontsize=12)
plt.title('Acceptance Rate vs. Number of Split Intervals')
plt.grid(True)
plt.legend(loc='best')
plt.show()
